# %% [markdown]
# Introduction to TensorFlow for Artificial Intelligence, Machine Learning, and Deep Learning
# - by Laurence Moroney
#
# Author : Abhinav Paul || Created : 20/04/2020 || Modified : 20/04/2020
#
# Code practice for TensorFlow course from Deeplearning.ai
